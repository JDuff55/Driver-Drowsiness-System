# %%
# !pip install dlib
# Out:
# Collecting dlib
#   Downloading dlib-20.0.0.tar.gz (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 9.6 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... one
#   Preparing metadata (pyproject.toml) ... one
# Building wheels for collected packages: dlib
# done
#   Created wheel for dlib: filename=dlib-20.0.0-cp313-cp313-macosx_12_0_x86_64.whl size=3927704 sha256=46b5406360fc0eaaaaa78f0be7cbd93c66da90cdebc409227248bbd63964cf12
#   Stored in directory: /Users/jackduff/Library/Caches/pip/wheels/d4/0d/ef/354663d702c37ab4b234126cfc6b61cfb36eda5ba193613a2c
# Successfully built dlib
# Installing collected packages: dlib
# Successfully installed dlib-20.0.0

# %%
# !pip install firebase-admin
# Out:
# Collecting firebase-admin
#   Downloading firebase_admin-7.1.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting cachecontrol>=0.14.3 (from firebase-admin)
#   Downloading cachecontrol-0.14.4-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-api-core<3.0.0dev,>=2.25.1 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-firestore>=2.21.0 (from firebase-admin)
#   Downloading google_cloud_firestore-2.21.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting google-cloud-storage>=3.1.1 (from firebase-admin)
#   Downloading google_cloud_storage-3.7.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pyjwt>=2.10.1 in /Applications/anaconda3/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->firebase-admin) (2.10.1)
# Requirement already satisfied: httpx==0.28.1 in /Applications/anaconda3/lib/python3.13/site-packages (from httpx[http2]==0.28.1->firebase-admin) (0.28.1)
# Requirement already satisfied: anyio in /Applications/anaconda3/lib/python3.13/site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (4.7.0)
# Requirement already satisfied: certifi in /Applications/anaconda3/lib/python3.13/site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Applications/anaconda3/lib/python3.13/site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.0.9)
# Requirement already satisfied: idna in /Applications/anaconda3/lib/python3.13/site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (3.7)
# Collecting h2<5,>=3 (from httpx[http2]==0.28.1->firebase-admin)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Applications/anaconda3/lib/python3.13/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (5.29.3)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Applications/anaconda3/lib/python3.13/site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.32.3)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading grpcio-1.76.0-cp313-cp313-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading grpcio_status-1.76.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Applications/anaconda3/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions~=4.12 in /Applications/anaconda3/lib/python3.13/site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (4.12.2)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: h11>=0.16 in /Applications/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Applications/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Applications/anaconda3/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.8)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /Applications/anaconda3/lib/python3.13/site-packages (from cachecontrol>=0.14.3->firebase-admin) (1.0.3)
# Collecting google-cloud-core<3.0.0,>=1.4.1 (from google-cloud-firestore>=2.21.0->firebase-admin)
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage>=3.1.1->firebase-admin)
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage>=3.1.1->firebase-admin)
#   Downloading google_crc32c-1.7.1-cp313-cp313-macosx_12_0_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: cryptography>=3.4.0 in /Applications/anaconda3/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->firebase-admin) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in /Applications/anaconda3/lib/python3.13/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin) (1.17.1)
# Requirement already satisfied: pycparser in /Applications/anaconda3/lib/python3.13/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin) (2.21)
# Requirement already satisfied: sniffio>=1.1 in /Applications/anaconda3/lib/python3.13/site-packages (from anyio->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.3.0)
# Downloading firebase_admin-7.1.0-py3-none-any.whl (137 kB)
# Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading grpcio-1.76.0-cp313-cp313-macosx_11_0_universal2.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 2.2 MB/s eta 0:00:0000:0100:01
# Downloading grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading cachecontrol-0.14.4-py3-none-any.whl (22 kB)
# Downloading google_cloud_firestore-2.21.0-py3-none-any.whl (368 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_cloud_storage-3.7.0-py3-none-any.whl (303 kB)
# Downloading google_crc32c-1.7.1-cp313-cp313-macosx_12_0_x86_64.whl (30 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Installing collected packages: rsa, protobuf, hyperframe, hpack, grpcio, google-crc32c, proto-plus, h2, googleapis-common-protos, google-resumable-media, google-auth, cachecontrol, grpcio-status, google-api-core, google-cloud-core, google-cloud-storage, google-cloud-firestore, firebase-admin
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3━━━━━━━━━━━━━━━━━━  1/18 [protobuf]
#     Uninstalling protobuf-5.29.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/18 [protobuf]
#       Successfully uninstalled protobuf-5.29.3━━━━━━━━━━━━━━━━  1/18 [protobuf]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [firebase-admin]m [firebase-admin]restore]s]
# Successfully installed cachecontrol-0.14.4 firebase-admin-7.1.0 google-api-core-2.28.1 google-auth-2.43.0 google-cloud-core-2.5.0 google-cloud-firestore-2.21.0 google-cloud-storage-3.7.0 google-crc32c-1.7.1 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 grpcio-1.76.0 grpcio-status-1.76.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 proto-plus-1.26.1 protobuf-6.33.2 rsa-4.9.1

# %%
import cv2
import dlib
import numpy as np
from scipy.spatial import distance
import firebase_admin
from firebase_admin import credentials, db
import time

# FIREBASE INITIALIZATION

cred = credentials.Certificate("serviceAccountKey.json")

# Initialize Firebase app
firebase_admin.initialize_app(cred, {
    "databaseURL": "https://driver-drowsiness-system-d98d9-default-rtdb.firebaseio.com/"
})


events_ref = db.reference("drowsiness_events")


# FUNCTION to send event to Firebase
def send_firebase_event():
    event_data = {
        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        "event": "DROWSINESS DETECTED"
    }
    events_ref.push(event_data)
    print("Firebase event uploaded:", event_data)



# EAR FUNCTION
def eye_aspect_ratio(eye):
    A = distance.euclidean(eye[1], eye[5])
    B = distance.euclidean(eye[2], eye[4])
    C = distance.euclidean(eye[0], eye[3])
    ear = (A + B) / (2.0 * C)
    return ear


# DLIB SETUP
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

LEFT_EYE = list(range(36, 42))
RIGHT_EYE = list(range(42, 48))

EAR_THRESHOLD = 0.25
CONSEC_FRAMES = 15
blink_counter = 0
sent_event = False   # prevents spamming Firebase



# VIDEO STREAM
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = detector(gray)

    for face in faces:
        shape = predictor(gray, face)
        landmarks = np.array([[p.x, p.y] for p in shape.parts()])

        left_eye = landmarks[LEFT_EYE]
        right_eye = landmarks[RIGHT_EYE]

        left_ear = eye_aspect_ratio(left_eye)
        right_ear = eye_aspect_ratio(right_eye)
        ear = (left_ear + right_ear) / 2.0

        # Draw eye points
        for (x, y) in np.concatenate((left_eye, right_eye)):
            cv2.circle(frame, (x, y), 2, (0, 255, 0), -1)

        # Drowsiness detection
        if ear < EAR_THRESHOLD:
            blink_counter += 1

            if blink_counter >= CONSEC_FRAMES:
                cv2.putText(frame, "DROWSY!", (50, 50),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                print("DROWSY! [ALERT]")

                if not sent_event:   # avoid multiple uploads
                    send_firebase_event()
                    sent_event = True

        else:
            blink_counter = 0
            sent_event = False  # allow next event
            print("[ALERT OFF]")

    cv2.imshow("EAR Drowsiness Detection", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

# CLEANUP
cap.release()
cv2.destroyAllWindows()
# Out:
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
# [ALERT OFF]
